# %% [markdown]
# <a href="https://colab.research.google.com/github/SaraaAlsukhni/Arabic-Text-Classification-/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 886.3/886.3 kB 33.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('yolov8x')
# Out:
# ...
# 100%|██████████| 131M/131M [00:00<00:00, 314MB/s]

# %%
result = model.predict('/content/08fd33_4.mp4', save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/750) /content/08fd33_4.mp4: 384x640 23 persons, 1 sports ball, 3420.5ms
# video 1/1 (frame 2/750) /content/08fd33_4.mp4: 384x640 23 persons, 1 sports ball, 2408.5ms
# video 1/1 (frame 3/750) /content/08fd33_4.mp4: 384x640 25 persons, 1 sports ball, 1 tv, 2325.4ms
# video 1/1 (frame 4/750) /content/08fd33_4.mp4: 384x640 25 persons, 1 sports ball, 1 tv, 2325.7ms
# ...

# %%
print(result[0])
print("==============================================")
for box in result[0].boxes:
  print(box)
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="uIO5QLrV0eHUKbILpWsJ")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(12)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-12 in yolov8:: 100%|██████████| 756/756 [00:00<00:00, 935.14it/s]

# %%
dataset.location
# Out:
# '/content/football-players-detection-12'

# %%
# !yolo task=detect mode=train model=yolov8x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.31 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
model = YOLO('/content/runs/detect/train/weights/best.pt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-cf554451a903> in <cell line: 1>()
# ----> 1 model = YOLO('/content/runs/detect/train/weights/best.pt')
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/models/yolo/model.py in __init__(self, model, task, verbose)
#      21         else:
#      22             # Continue with default YOLO initialization
# ---> 23             super().__init__(model=model, task=task, verbose=verbose)
#      24
#      25     @property
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py in __init__(self, model, task, verbose)
#     143             self._new(model, task=task, verbose=verbose)
#     144         else:
# --> 145             self._load(model, task=task)
#     146
#     147     def __call__(
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py in _load(self, weights, task)
# ...
